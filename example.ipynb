# %%
import maintools as tools
import main_run

# %% [markdown]
# ------
# ## Video location

# %%
file = 'videos/video_test_1.mp4'

# %% [markdown]
# ------
# ## Running Marker-less | Get Hip and Knee 2D Joint Angles

# %%
main_run.run_markerless(video_path=file, side='r', save=True, show=True, min_confidence=0.9, scale_factor=0.3)
# Out:
# -----------------------------------
# Calculating Hip and Knee Flexion:
#
# Video Path: videos/video_test_1.mp4
# Side: r
# Save: True
# Show: True
# min_confidence: 0.9
# scale_factor: 0.2
# Saving results to: videos/results/video_test_1
#
# Calculating Joint angles:
# Joint Angles | Hip: 0.54 - Knee: 2.27
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 main_run.run_markerless(video_path=file, side='r', save=True, show=True, min_confidence=0.9, scale_factor=0.2)
#
# File d:\bruno\mediapipe2dangle\main_run.py:232, in run_markerless(video_path, side, save, show, min_confidence, scale_factor)
#     229 output_df = os.path.join(res_folder, f'{main_name}_markerless_{side}.csv')
#     231 # Process the video and save results
# ...
