# %%
import maintools as tools
import main_run

# %% [markdown]
# ------
# ## Video location

# %%
file = 'videos/video_test_2.mp4'

# %% [markdown]
# ------
# ## Running Marker-less | Get Hip and Knee 2D Joint Angles

# %%
main_run.run_markerless(video_path=file, side='r', save=True, show=True, min_confidence=0.9, scale_factor=0.5)
# Out:
# -----------------------------------
# Calculating Hip and Knee Flexion:
#
# Video Path: videos/video_test_2.mp4
# Side: r
# Save: True
# Show: True
# min_confidence: 0.9
# scale_factor: 0.5
# Saving results to: videos/results/video_test_2
#
# Calculating Joint angles:
# Joint Angles | Hip: 8.54 - Knee: 1.01338     Frame  Knee_Angle  Hip_Angle
# 0        0    0.067722   5.373834
# 1        1    0.614008   6.163838
# 2        2    0.823807   6.533953
# 3        3    0.666514   6.781075
# 4        4    1.018795   7.536201
# ..     ...         ...        ...
# 288    288    1.805967   9.271228
# 289    289    1.331351   9.033450
# 290    290    1.004668   8.611706
# 291    291    0.934079   8.414592
# 292    292    1.009163   8.536564
#
# [293 rows x 3 columns]
# videos/results/video_test_2\video_test_2_markerless_r.csv
